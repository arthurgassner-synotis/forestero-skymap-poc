# %%
from pystac_client import Client
import joblib
from typing import Any
import os
import requests
from datetime import date

# %%
from utils.constants import GHANA, SENTINEL_SCENES_FOLDERPATH, SILVER_FOLDERPATH, EARCH_SEARCH_API_URL, SENTINEL_BANDS
from utils.site import Site
from utils.search_result import SearchResult

# %%
# Load search_results
search_results = joblib.load(SILVER_FOLDERPATH / "search_results.pkl")
print(f"Loaded {len(search_results)} search results")
# Out:
# Loaded 3 search results

# %%
# E.G.
sr = search_results[0]
scene = sr.scenes[0]
for band in SENTINEL_BANDS:
    if band in scene.assets:
        download_url = scene.assets[band].href
        print(f"{band.upper()}: {download_url}")
# Out:
# BLUE: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/30/N/XM/2022/1/S2B_30NXM_20220126_0_L2A/B02.tif
# GREEN: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/30/N/XM/2022/1/S2B_30NXM_20220126_0_L2A/B03.tif
# RED: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/30/N/XM/2022/1/S2B_30NXM_20220126_0_L2A/B04.tif
# NIR: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/30/N/XM/2022/1/S2B_30NXM_20220126_0_L2A/B08.tif
# SWIR22: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/30/N/XM/2022/1/S2B_30NXM_20220126_0_L2A/B12.tif

# %%
# Download a single 2020 scene, if any
for sr in search_results:
    sr.keep(min_date=date(2020,1,1), max_date=date(2020,2,1))
    sr.keep_least_cloudy()
    sr.download()
# Out:
# 2026-04-08 11:59:01.116 | INFO     | utils.search_result:download:111 - Downloading 1 scenes ...
# 2026-04-08 11:59:01.119 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_blue.tif already exists. Skipping...
# 2026-04-08 11:59:01.120 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_green.tif already exists. Skipping...
# 2026-04-08 11:59:01.122 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_red.tif already exists. Skipping...
# 2026-04-08 11:59:01.123 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_nir.tif already exists. Skipping...
# 2026-04-08 11:59:01.124 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_swir22.tif already exists. Skipping...
# 2026-04-08 11:59:01.125 | INFO     | utils.search_result:download:111 - Downloading 1 scenes ...
# 2026-04-08 11:59:01.127 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_blue.tif already exists. Skipping...
# 2026-04-08 11:59:01.128 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_green.tif already exists. Skipping...
# 2026-04-08 11:59:01.131 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_red.tif already exists. Skipping...
# 2026-04-08 11:59:01.132 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_nir.tif already exists. Skipping...
# 2026-04-08 11:59:01.133 | WARNING  | utils.search_result:download_file:85 - File /home/aga/Documents/clients/forestero/skymap/skymap/data/bronze/sentinel-scenes/S2B_30NXM_20200107_1_L2A/S2B_30NXM_20200107_1_L2A_swir22.tif already exists. Skipping...
# 2026-04-08 11:59:01.135 | INFO     | utils.search_result:download:111 - Downloading 1 scenes ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 # Download a single 2020 scene, if any
#       2 for sr in search_results:
#       3     sr.keep(min_date=date(2020,1,1), max_date=date(2020,2,1))
#       4     sr.keep_least_cloudy()
# ----> 5     sr.download()
#
# File ~/Documents/clients/forestero/skymap/skymap/nb/utils/search_result.py:124, in SearchResult.download(self)
#     121 filepath = scene_folder / filename
#     123 try:
# --> 124     SearchResult.download_file(download_url, filepath)
#     125 except Exception as e:
#     126     logger.exception(f"Error downloading {band}: {e}")
#
# File ~/Documents/clients/forestero/skymap/skymap/nb/utils/search_result.py:99, in SearchResult.download_file(url, filepath)
#      93 total_size = int(response.headers.get("content-length", 0))
#      95 with (
#      96     part_filepath.open("wb") as f,
#      97     tqdm(desc=filepath.name, total=total_size, unit="iB", unit_scale=True, unit_divisor=1024, leave=False) as bar,
#      98 ):
# ---> 99     for chunk in response.iter_content(chunk_size=8192):
#     100         if chunk:
#     101             size = f.write(chunk)
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820 if hasattr(self.raw, "stream"):
#     821     try:
# --> 822         yield from self.raw.stream(chunk_size, decode_content=True)
#     823     except ProtocolError as e:
#     824         raise ChunkedEncodingError(e)
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/urllib3/response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/urllib3/response.py:1091, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1065 def read(
#    1066     self,
#    1067     amt: int | None = None,
#    1068     decode_content: bool | None = None,
#    1069     cache_content: bool = False,
#    1070 ) -> bytes:
#    1071     """
#    1072     Similar to :meth:`http.client.HTTPResponse.read`, but with two additional
#    1073     parameters: ``decode_content`` and ``cache_content``.
#    (...)   1089         set.)
#    1090     """
# -> 1091     self._init_decoder()
#    1092     if decode_content is None:
#    1093         decode_content = self.decode_content
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/urllib3/response.py:606, in BaseHTTPResponse._init_decoder(self)
#     601 """
#     602 Set-up the _decoder attribute if necessary.
#     603 """
#     604 # Note: content-encoding value should be case-insensitive, per RFC 7230
#     605 # Section 3.2
# --> 606 content_encoding = self.headers.get("content-encoding", "").lower()
#     607 if self._decoder is None:
#     608     if content_encoding in self.CONTENT_DECODERS:
#
# File <frozen _collections_abc>:796, in Mapping.get(self, key, default)
#     792     def get(self, key, default=None):
#     793         'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     794         try:
#     795             return self[key]
# --> 796         except KeyError:
#     797             return default
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/urllib3/_collections.py:260, in HTTPHeaderDict.__getitem__(self, key)
#     258 if isinstance(key, bytes):
#     259     key = key.decode("latin-1")
# --> 260 val = self._container[key.lower()]
#     261 return ", ".join(val[1:])
#
# KeyboardInterrupt:
