# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from pathlib import Path
from dataclasses import dataclass
import numpy as np
from rasterio.warp import transform_bounds
from datetime import datetime, date
import joblib

# %%
from utils.constants import GHANA, SENTINEL_SCENES_FOLDERPATH, SILVER_FOLDERPATH
from utils.search_result import SearchResult
from utils.site import Site
from utils.sentinel_scene import SentinelScene

# %%
# Load sites
sites = joblib.load(SILVER_FOLDERPATH / "sites.pkl")
print(f"Loaded {len(sites)} sites")
# Out:
# Loaded 155 sites

# %%
# Load search_results
search_results = joblib.load(SILVER_FOLDERPATH / "search_results.pkl")
print(f"Loaded {len(search_results)} search results")
# Out:
# Loaded 155 search results

# %%
for s in sites:
    s.add_scenes(search_results)
# Out:
# 2026-04-08 13:54:19.834 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:19.843 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:19.852 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.861 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.873 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.885 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.896 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.905 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:19.915 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:19.927 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:19.937 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:19.944 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:19.953 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:19.961 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.968 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.977 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.989 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:19.999 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:20.007 | INFO     | utils.site:add_scenes:51 - Added 76 scenes (76 total)
# 2026-04-08 13:54:20.013 | INFO     | utils.site:add_scenes:51 - Added 76 scenes (76 total)
# 2026-04-08 13:54:20.019 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.027 | INFO     | utils.site:add_scenes:51 - Added 57 scenes (57 total)
# 2026-04-08 13:54:20.039 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.048 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.072 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.102 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.129 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.163 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.176 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.186 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.194 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.201 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.218 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.238 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.262 | INFO     | utils.site:add_scenes:51 - Added 48 scenes (48 total)
# 2026-04-08 13:54:20.272 | INFO     | utils.site:add_scenes:51 - Added 48 scenes (48 total)
# 2026-04-08 13:54:20.279 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.285 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.291 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.304 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:20.320 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:20.329 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:20.335 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:20.341 | INFO     | utils.site:add_scenes:51 - Added 35 scenes (35 total)
# 2026-04-08 13:54:20.354 | INFO     | utils.site:add_scenes:51 - Added 19 scenes (19 total)
# 2026-04-08 13:54:20.361 | INFO     | utils.site:add_scenes:51 - Added 30 scenes (30 total)
# 2026-04-08 13:54:20.381 | INFO     | utils.site:add_scenes:51 - Added 30 scenes (30 total)
# 2026-04-08 13:54:20.387 | INFO     | utils.site:add_scenes:51 - Added 30 scenes (30 total)
# 2026-04-08 13:54:20.393 | INFO     | utils.site:add_scenes:51 - Added 11 scenes (11 total)
# 2026-04-08 13:54:20.406 | INFO     | utils.site:add_scenes:51 - Added 11 scenes (11 total)
# 2026-04-08 13:54:20.412 | INFO     | utils.site:add_scenes:51 - Added 29 scenes (29 total)
# 2026-04-08 13:54:20.418 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:20.427 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.435 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:20.448 | INFO     | utils.site:add_scenes:51 - Added 65 scenes (65 total)
# 2026-04-08 13:54:20.454 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:20.460 | INFO     | utils.site:add_scenes:51 - Added 53 scenes (53 total)
# 2026-04-08 13:54:20.473 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.481 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.499 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.522 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.538 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.551 | INFO     | utils.site:add_scenes:51 - Added 71 scenes (71 total)
# 2026-04-08 13:54:20.564 | INFO     | utils.site:add_scenes:51 - Added 71 scenes (71 total)
# 2026-04-08 13:54:20.572 | INFO     | utils.site:add_scenes:51 - Added 71 scenes (71 total)
# 2026-04-08 13:54:20.578 | INFO     | utils.site:add_scenes:51 - Added 71 scenes (71 total)
# 2026-04-08 13:54:20.587 | INFO     | utils.site:add_scenes:51 - Added 153 scenes (153 total)
# 2026-04-08 13:54:20.603 | INFO     | utils.site:add_scenes:51 - Added 84 scenes (84 total)
# 2026-04-08 13:54:20.615 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.621 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.626 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.632 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.637 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.643 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.648 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.661 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.670 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.678 | INFO     | utils.site:add_scenes:51 - Added 30 scenes (30 total)
# 2026-04-08 13:54:20.684 | INFO     | utils.site:add_scenes:51 - Added 30 scenes (30 total)
# 2026-04-08 13:54:20.695 | INFO     | utils.site:add_scenes:51 - Added 91 scenes (91 total)
# 2026-04-08 13:54:20.707 | INFO     | utils.site:add_scenes:51 - Added 57 scenes (57 total)
# 2026-04-08 13:54:20.713 | INFO     | utils.site:add_scenes:51 - Added 38 scenes (38 total)
# 2026-04-08 13:54:20.719 | INFO     | utils.site:add_scenes:51 - Added 38 scenes (38 total)
# 2026-04-08 13:54:20.725 | INFO     | utils.site:add_scenes:51 - Added 38 scenes (38 total)
# 2026-04-08 13:54:20.746 | INFO     | utils.site:add_scenes:51 - Added 38 scenes (38 total)
# 2026-04-08 13:54:20.761 | INFO     | utils.site:add_scenes:51 - Added 66 scenes (66 total)
# 2026-04-08 13:54:20.774 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.788 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.802 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.812 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.818 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.824 | INFO     | utils.site:add_scenes:51 - Added 66 scenes (66 total)
# 2026-04-08 13:54:20.830 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.836 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.844 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.851 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.864 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.875 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:20.881 | INFO     | utils.site:add_scenes:51 - Added 57 scenes (57 total)
# 2026-04-08 13:54:20.886 | INFO     | utils.site:add_scenes:51 - Added 57 scenes (57 total)
# 2026-04-08 13:54:20.891 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.898 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.904 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.909 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.914 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.919 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.925 | INFO     | utils.site:add_scenes:51 - Added 71 scenes (71 total)
# 2026-04-08 13:54:20.937 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.942 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.947 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.953 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.965 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.982 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:20.991 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.001 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.007 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.013 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.027 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.059 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.085 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.110 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.138 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.152 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.164 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.181 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.191 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.214 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.245 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.267 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:21.285 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:21.294 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:21.305 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:21.328 | INFO     | utils.site:add_scenes:51 - Added 33 scenes (33 total)
# 2026-04-08 13:54:21.336 | INFO     | utils.site:add_scenes:51 - Added 66 scenes (66 total)
# 2026-04-08 13:54:21.345 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.355 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.378 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.389 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.400 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.416 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.429 | INFO     | utils.site:add_scenes:51 - Added 43 scenes (43 total)
# 2026-04-08 13:54:21.443 | INFO     | utils.site:add_scenes:51 - Added 57 scenes (57 total)
# 2026-04-08 13:54:21.462 | INFO     | utils.site:add_scenes:51 - Added 69 scenes (69 total)
# 2026-04-08 13:54:21.479 | INFO     | utils.site:add_scenes:51 - Added 69 scenes (69 total)
# 2026-04-08 13:54:21.488 | INFO     | utils.site:add_scenes:51 - Added 38 scenes (38 total)
# 2026-04-08 13:54:21.499 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.507 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.526 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.539 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.561 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.583 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.590 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.611 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.630 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)
# 2026-04-08 13:54:21.637 | INFO     | utils.site:add_scenes:51 - Added 24 scenes (24 total)

# %%
joblib.dump(sites, SILVER_FOLDERPATH / "enriched-sites.pkl")
# Out:
# ['/home/aga/Documents/clients/forestero/skymap/skymap/data/silver/enriched-sites.pkl']
