# %%
# %load_ext autoreload
# %autoreload 2

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from pathlib import Path
from dataclasses import dataclass
import numpy as np
from rasterio.warp import transform_bounds
from datetime import datetime, date
import joblib

# %%
from utils.constants import SENTINEL_SCENES_FOLDERPATH, SILVER_FOLDERPATH
from utils.search_result import SearchResult
from utils.site import Site
from utils.sentinel_scene import SentinelScene

# %%
# Load sites
sites = joblib.load(SILVER_FOLDERPATH / "enriched-sites.pkl")
print(f"Loaded {len(sites)} sites")
# Out:
# Loaded 155 sites

# %%
s = [e for e in sites if e.name == "FO01"][0]

# %%
ss = s.sentinel_scenes[0]
ss.plot([(lon, lat) for lat, lon in s.lat_lons], padding_m=500, plot_scale=2.0)

# %%
ss = s.sentinel_scenes[1]
ss.plot([(lon, lat) for lat, lon in s.lat_lons], padding_m=500, plot_scale=2.0)

# %%
s.plot_over_scenes(padding_m=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s.plot_over_scenes(padding_m=50)
#
# File ~/Documents/clients/forestero/skymap/skymap/nb/utils/site.py:96, in Site.plot_over_scenes(self, padding_m)
#      93 bounds = cropped_ss.bounds
#      94 extent = (0, bounds.right - bounds.left, 0, bounds.top - bounds.bottom)
# ---> 96 ax.imshow(cropped_ss.processed_rgb, extent=extent)
#      98 # Plot the area
#      99 gs = self.gs.to_crs(ss.crs)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imshow'

# %%
# Out:
# {'S2A_30NYM_20200112_1_L2A'}
