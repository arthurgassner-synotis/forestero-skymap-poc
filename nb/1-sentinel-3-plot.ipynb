# %%
# %load_ext autoreload
# %autoreload 2

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from pathlib import Path
from dataclasses import dataclass
import numpy as np
from rasterio.warp import transform_bounds
from datetime import datetime, date
import joblib

# %%
from utils.constants import SENTINEL_SCENES_FOLDERPATH, SILVER_FOLDERPATH
from utils.search_result import SearchResult
from utils.site import Site
from utils.sentinel_scene import SentinelScene

# %%
# Load sites
sites = joblib.load(SILVER_FOLDERPATH / "enriched-sites.pkl")
print(f"Loaded {len(sites)} sites")
# Out:
# Loaded 155 sites

# %%
s = [e for e in sites if e.name == "FO01"][0]
ss = s.sentinel_scenes[0]

# %%
ss.plot([(lon, lat) for lat, lon in s.lat_lons], padding_m=500)

# %%
s.plot_over_scenes(padding_m=10)
# Out:
# (-1.071492, 5.901034, -1.071322, 5.901277)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s.plot_over_scenes(padding_m=10)
#
# File ~/Documents/clients/forestero/skymap/skymap/nb/utils/site.py:84, in Site.plot_over_scenes(self, padding_m)
#      81     axes = [axes]
#      83 for ax, ss in zip(axes, self.sentinel_scenes):
# ---> 84     cropped_ss = ss.crop(self.bbox, padding_m=padding_m)
#      86     # Figure out ticks
#      87     bounds = cropped_ss._bounds
#
# File ~/Documents/clients/forestero/skymap/skymap/nb/utils/sentinel_scene.py:5, in crop(self, lon_lats, padding_m)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/shapely/geometry/multipoint.py:64, in MultiPoint.__new__(self, points)
#      62 subs = []
#      63 for item in points:
# ---> 64     p = point.Point(item)
#      65     if p.is_empty:
#      66         raise EmptyPartError("Can't create MultiPoint with empty component")
#
# File ~/Documents/clients/forestero/skymap/skymap/.venv/lib/python3.14/site-packages/shapely/geometry/point.py:69, in Point.__new__(self, *args)
#      67     # Accept either (x, y) or [(x, y)]
#      68     if not hasattr(coords, "__getitem__"):  # generators
# ---> 69         coords = list(coords)
#      70     coords = np.asarray(coords).squeeze()
#      71 else:
#      72     # 2 or 3 args
#
# TypeError: 'float' object is not iterable
